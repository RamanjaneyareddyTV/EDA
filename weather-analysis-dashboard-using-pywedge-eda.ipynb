# %% [markdown]
# ![Droplets on Glass Email Header(1).jpg](attachment:f33dbe25-575f-4035-ae31-8c51468130ad.jpg)

# %% [markdown]
# <blockquote>This notebook contains Exploratary Data Analysis on Weather Dataset and creation of Dashboard using Pywedge 0.5.1.8 Python package. The dataset contains 96453 entries and 12 attributes related to meteorological data.</blockquote>

# %% [markdown]
# ### <h3 style="background-color:#6c757d;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>Importing Libraries & Packages 📚 </centre></strong></h3>

# %%
# getting started with the model 
# importing required libraries/packages 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### <h3 style="background-color:#6c757d;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>Importing & Reading the dataset 📝 </centre></strong></h3>

# %%
df_weather= pd.read_csv("weatherHistory.csv")

# %%
df_weather_row_count, df_weather_column_count=df_weather.shape
print('Total number of rows:', df_weather_row_count)
print('Total number of columns:', df_weather_column_count)
# Out:
# Total number of rows: 96453
# Total number of columns: 11

# %% [markdown]
# ### <h3 style="background-color:#6c757d;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>Checking for datatypes, unique values & missing values✏️ </centre></strong></h3>

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  int64
#  8   Visibility (km)           96453 non-null  float64
#  9   Pressure (millibars)      96453 non-null  float64
#  10  Daily Summary             96453 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 8.1+ MB

# %%
print ("Unique values are:\n",df_weather.nunique())
# Out:
# Unique values are:
#  Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
Summary_Weather=df_weather["Summary"].value_counts().reset_index()
Summary_Weather.columns=["Weather Type","Count"]
Summary_Weather
# Out:
#                            Weather Type  Count
# 0                         Partly Cloudy  31733
# 1                         Mostly Cloudy  28094
# 2                              Overcast  16597
# 3                                 Clear  10890
# 4                                 Foggy   7148
# 5                   Breezy and Overcast    528
# 6              Breezy and Mostly Cloudy    516
# 7              Breezy and Partly Cloudy    386
# 8                 Dry and Partly Cloudy     86
# 9               Windy and Partly Cloudy     67
# 10                           Light Rain     63
# 11                               Breezy     54
# 12                   Windy and Overcast     45
# 13              Humid and Mostly Cloudy     40
# 14                              Drizzle     39
# 15                     Breezy and Foggy     35
# 16              Windy and Mostly Cloudy     35
# 17                                  Dry     34
# 18              Humid and Partly Cloudy     17
# 19                Dry and Mostly Cloudy     14
# 20                                 Rain     10
# 21                                Windy      8
# 22                   Humid and Overcast      7
# 23                      Windy and Foggy      4
# 24                        Windy and Dry      1
# 25  Dangerously Windy and Partly Cloudy      1
# 26                       Breezy and Dry      1

# %%
wt_missing =df_weather.isna().sum()
wt_missing
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
t_cells = np.product(df_weather.shape)
t_missing = wt_missing.sum()
percent_missing = (t_missing/t_cells) * 100
print(percent_missing)
# Out:
# 0.04872839621369994

# %%
df_weather['Precip Type'].fillna(df_weather['Precip Type'].value_counts().index[0],inplace=True)
df_weather.isna().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
df_weather.isna().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
df_weather.head().iloc[:5]
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# 1                     259          15.8263               1015.63
# 2                     204          14.9569               1015.94
# 3                     269          15.8263               1016.41
# 4                     259          15.8263               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
#checking Datatypes
df_weather.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)        int64
# Visibility (km)             float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
import datetime as dt
from datetime import timedelta

# %%
df_weather["Formatted Date"]=pd.to_datetime(df_weather["Formatted Date"])

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.barplot(data=df_weather, x="Summary", y="Temperature (C)",hue="Precip Type")
# Out:
# <AxesSubplot:xlabel='Summary', ylabel='Temperature (C)'>

# %%
plt.figure(figsize=(7,5))
plt.xticks(rotation=90)
sns.lineplot(data=df_weather, x="Summary", y="Pressure (millibars)", hue="Precip Type", style="Precip Type")
# Out:
# <AxesSubplot:xlabel='Summary', ylabel='Pressure (millibars)'>

# %%
sns.pairplot(df_weather,hue="Humidity")

# %% [markdown]
# ### <h3 style="background-color:#6c757d;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;"><strong><centre>Creating Weather Dashboard</centre></strong></h3>

# %% [markdown]
# <blockquote>⚙️ Install Pywedge using pip command & Import Libraries🔧 </blockquote>

# %%
# !pip install pywedge
# Out:
# Requirement already satisfied: pywedge in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (0.5.1.8)
# Requirement already satisfied: plotly in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pywedge) (5.4.0)
# Requirement already satisfied: numpy in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pywedge) (1.19.5)
# Requirement already satisfied: ipywidgets in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pywedge) (7.6.5)
# Requirement already satisfied: pandas in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pywedge) (1.3.4)
# Requirement already satisfied: tqdm in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pywedge) (4.62.3)
# Requirement already satisfied: catboost>0.24 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pywedge) (1.0.3)
# Requirement already satisfied: scikit-learn in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pywedge) (1.0.1)
# Requirement already satisfied: xgboost in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pywedge) (1.5.1)
# Requirement already satisfied: imbalanced-learn in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pywedge) (0.8.1)
# Requirement already satisfied: matplotlib in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from catboost>0.24->pywedge) (3.5.0)
# Requirement already satisfied: graphviz in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from catboost>0.24->pywedge) (0.19.1)
# Requirement already satisfied: scipy in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from catboost>0.24->pywedge) (1.7.3)
# Requirement already satisfied: six in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from catboost>0.24->pywedge) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pandas->pywedge) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from pandas->pywedge) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from imbalanced-learn->pywedge) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn->pywedge) (3.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->pywedge) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->pywedge) (6.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->pywedge) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->pywedge) (1.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->pywedge) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->pywedge) (5.1.3)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->pywedge) (7.30.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (7.1.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (0.1.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (1.5.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (3.0.23)
# Requirement already satisfied: pygments in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (2.10.0)
# Requirement already satisfied: colorama in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (0.18.1)
# Requirement already satisfied: decorator in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (58.1.0)
# Requirement already satisfied: backcall in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->pywedge) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pywedge) (4.9.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pywedge) (22.3.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pywedge) (1.5.1)
# Requirement already satisfied: entrypoints in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pywedge) (0.3)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Ramanjaneyareddy\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pywin32>=1.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pywedge) (302)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pywedge) (4.2.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pywedge) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pywedge) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->pywedge) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pywedge) (6.4.6)
# Requirement already satisfied: argon2-cffi in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (21.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.12.1)
# Requirement already satisfied: nbconvert in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (6.3.0)
# Requirement already satisfied: jinja2 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (3.0.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.12.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (1.1.6)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost>0.24->pywedge) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost>0.24->pywedge) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost>0.24->pywedge) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost>0.24->pywedge) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost>0.24->pywedge) (3.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost>0.24->pywedge) (4.28.2)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost>0.24->pywedge) (6.3.2)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from setuptools-scm>=4->matplotlib->catboost>0.24->pywedge) (1.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.5.9)
# Requirement already satisfied: testpath in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.5.0)
# Requirement already satisfied: bleach in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (4.1.0)
# Requirement already satisfied: webencodings in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.5.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ramanjaneyareddy\appdata\local\programs\python\python39\lib\site-packages (from plotly->pywedge) (8.0.1)

# %%
import pywedge as pw

# %%
x=pw.Pywedge_Charts(df_weather,c=None,y="Humidity")
charts=x.make_charts()
# Out:
# HTML(value='<h2>Pywedge Make_Charts </h2>')
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), _titles={'0': '…

# %% [markdown]
# <blockquote>📌 You can generate 8 different plots like Scatter Plot, Pie Chart, Bar Plot, Violin Plot, Box Plot, Distribution Plot, Histogram and Correlation Plot using Pywedge</blockquote>

# %% [markdown]
# ![image.png](attachment:ae324ee3-7ab0-4a90-831e-cbb931248152.png)

# %% [markdown]
# ![image.png](attachment:349adf4f-9955-428f-a931-7b528d752d6f.png)

# %% [markdown]
# ![image.png](attachment:3b0b44d1-c60a-4190-9110-1c32666e05a8.png)

# %% [markdown]
# ![image.png](attachment:26499801-ce6f-47ca-8e9c-fb6418828df9.png)

# %% [markdown]
# ![image.png](attachment:f5a3ea77-e88e-49ea-8187-f975ca1ba4c7.png)

# %% [markdown]
# ![image.png](attachment:db1e1862-259d-4614-8dd4-ffa9bc59a632.png)
